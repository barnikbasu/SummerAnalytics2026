# %%
print("Hello Summer Analytics")
# Out:
# Hello Summer Analytics

# %%
name = "Barnik"

print(name)
# Out:
# Barnik

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # My First Notebook
#
# Learning Jupyter Notebook for Summer Analytics 2026.

# %%
print(name)
# Out:
# Barnik
